# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www1.president.go.kr/petitions/best?page=10')

# %%
#cont_view > div.cs_area > div > div > div.board.text > div.b_list.category > div.bl_body > ul > lii

# %%
html = driver.page_source

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup.select('#cont_view > div.cs_area > div > div > div.board.text > div.b_list.category > div.bl_body > ul > li')
# Out:
# [<li>
#  <div class="bl_wrap">
#  <div class="bl_no"><span class="sound_only">번호 </span>499</div>
#  <div class="bl_category cs"><span class="sound_only">분류 </span> 교통/건축/국토</div>
#  <div class="bl_subject">
#  <a class="cb" href="/petitions/594092?navigation=best"><span class="sound_only">제목 </span>촉진 ****구역에 기생충처럼 붙어있는 서민들 등골 빼먹는 한국토지신탁 당장 해지하라!!!</a>
#  </div>
#  <span class="sound_only">청원만료 </span><div class="bl_date light">20-12-20</div>
#  <div class="bl_agree cb wv_agree">
#  <span class="sound_only">참여인원 </span>1,983명
#  												</div>
#  </div>
#  </li>,
#  <li>
#  <div class="bl_wrap">
#  <div class="bl_no"><span class="sound_only">번호 </span>498</div>
#  <div class="bl_category cs"><span class="sound_only">분류 </span> 행정</div>
#  <div class="bl_subject">
#  <a class="cb" href="/petitions/594162?navigation=best"><span class="sound_only">제목 </span>교통사고로 뇌출혈을 당한 피해자(신분증,명함소지)의 가족에게 단 한차례도 담당 조사관은 연…</a>
#  </div>
# ...
