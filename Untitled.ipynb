# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('data/Top250.csv')
df1.head()
# Out:
#    Rank   Restaurant                                            Content  \
# 0     1   McDonald's                                                NaN
# 1     2    Starbucks                                                NaN
# 2     3  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 3     4    Taco Bell                                                NaN
# 4     5  Burger King                                                NaN
#
#    Sales YOY_Sales  Units YOY_Units Headquarters             Segment_Category
# 0  40412      4.9%  13846     -0.5%          NaN       Quick Service & Burger
# 1  21380      8.6%  15049      3.0%          NaN  Quick Service & Coffee Cafe
# 2  11320     13.0%   2470      5.0%          NaN      Quick Service & Chicken
# 3  11293      9.0%   6766      2.7%          NaN      Quick Service & Mexican
# 4  10204      2.7%   7346      0.2%          NaN       Quick Service & Burger

# %%
df2 = pd.read_csv('data/Independence100.csv')
df2.head()
# Out:
#    Rank                           Restaurant       Sales  Average Check  \
# 0     1             Carmine's (Times Square)  39080335.0             40
# 1     2                The Boathouse Orlando  35218364.0             43
# 2     3                     Old Ebbitt Grill  29104017.0             33
# 3     4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4     5             Bryant Park Grill & Cafe  26900000.0             62
#
#          City State  Meals Served
# 0    New York  N.Y.      469803.0
# 1    Orlando   Fla.      820819.0
# 2  Washington  D.C.      892830.0
# 3    New York  N.Y.      198500.0
# 4    New York  N.Y.      403000.0

# %%
df3 = pd.read_csv('data/Future50.csv')
df3.head()
# Out:
#    Rank   Restaurant                  Location  Sales YOY_Sales  Units  \
# 0     1   Evergreens            Seattle, Wash.     24    130.5%     26
# 1     2  Clean Juice           Charlotte, N.C.     44    121.9%    105
# 2     3     Slapfish  Huntington Beach, Calif.     21     81.0%     21
# 3     4   Clean Eatz          Wilmington, N.C.     25     79.7%     46
# 4     5    Pokeworks            Irvine, Calif.     49     77.1%     50
#
#   YOY_Units  Unit_Volume Franchising
# 0    116.7%         1150          No
# 1     94.4%          560         Yes
# 2     90.9%         1370         Yes
# 3     58.6%          685         Yes
# 4     56.3%         1210         Yes

# %%
df1
# Out:
#      Rank           Restaurant  \
# 0       1           McDonald's
# 1       2            Starbucks
# 2       3          Chick-fil-A
# 3       4            Taco Bell
# 4       5          Burger King
# ..    ...                  ...
# 245   246      Rainforest Cafe
# 246   247                  PDQ
# 247   248        Lupe Tortilla
# 248   249  Cook-Out Restaurant
# 249   250             Jollibee
#
#                                                Content  Sales YOY_Sales  \
# 0                                                  NaN  40412      4.9%
# 1                                                  NaN  21380      8.6%
# 2    While Popeyes got a lot of the chicken buzz in...  11320     13.0%
# 3                                                  NaN  11293      9.0%
# 4                                                  NaN  10204      2.7%
# ..                                                 ...    ...       ...
# 245                                                NaN    129    -10.4%
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              250 non-null    int64
#  1   Restaurant        250 non-null    object
#  2   Content           33 non-null     object
#  3   Sales             250 non-null    int64
#  4   YOY_Sales         250 non-null    object
#  5   Units             250 non-null    int64
#  6   YOY_Units         250 non-null    object
#  7   Headquarters      52 non-null     object
#  8   Segment_Category  250 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 17.7+ KB

# %%
df1.columns = ['랭킹','레스토랑이름','함유량','매상','전년대비증가율','미국내건물수','전년대비','식당본사소재지','메뉴&서비스']

# %%
df1.head()
# Out:
#    랭킹       레스토랑이름                                                함유량     매상  \
# 0   1   McDonald's                                                NaN  40412
# 1   2    Starbucks                                                NaN  21380
# 2   3  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...  11320
# 3   4    Taco Bell                                                NaN  11293
# 4   5  Burger King                                                NaN  10204
#
#   전년대비증가율  미국내건물수   전년대비 식당본사소재지                       메뉴&서비스
# 0    4.9%   13846  -0.5%     NaN       Quick Service & Burger
# 1    8.6%   15049   3.0%     NaN  Quick Service & Coffee Cafe
# 2   13.0%    2470   5.0%     NaN      Quick Service & Chicken
# 3    9.0%    6766   2.7%     NaN      Quick Service & Mexican
# 4    2.7%    7346   0.2%     NaN       Quick Service & Burger

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   랭킹       250 non-null    int64
#  1   레스토랑이름   250 non-null    object
#  2   함유량      33 non-null     object
#  3   매상       250 non-null    int64
#  4   전년대비증가율  250 non-null    object
#  5   미국내건물수   250 non-null    int64
#  6   전년대비     250 non-null    object
#  7   식당본사소재지  52 non-null     object
#  8   메뉴&서비스   250 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 17.7+ KB

# %%
df1.drop(['함유량','식당본사소재지'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    랭킹       레스토랑이름     매상 전년대비증가율  미국내건물수   전년대비                       메뉴&서비스
# 0   1   McDonald's  40412    4.9%   13846  -0.5%       Quick Service & Burger
# 1   2    Starbucks  21380    8.6%   15049   3.0%  Quick Service & Coffee Cafe
# 2   3  Chick-fil-A  11320   13.0%    2470   5.0%      Quick Service & Chicken
# 3   4    Taco Bell  11293    9.0%    6766   2.7%      Quick Service & Mexican
# 4   5  Burger King  10204    2.7%    7346   0.2%       Quick Service & Burger

# %%
df1.isnull().sum()
# Out:
# 랭킹         0
# 레스토랑이름     0
# 매상         0
# 전년대비증가율    0
# 미국내건물수     0
# 전년대비       0
# 메뉴&서비스     0
# dtype: int64

# %%
df1.전년대비증가율.apply(lambda x:x.replace('%',''))
# Out:
# 0        4.9
# 1        8.6
# 2       13.0
# 3        9.0
# 4        2.7
#        ...
# 245    -10.4
# 246     -5.5
# 247     12.1
# 248     10.1
# 249     15.2
# Name: 전년대비증가율, Length: 250, dtype: object
